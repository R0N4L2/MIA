# %%
import zipfile
with zipfile.ZipFile('/content/drive/MyDrive/MIA/INF3831 - Bases de datos/Actividad_Data_Science.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/drive/MyDrive/MIA/INF3831 - Bases de datos/Actividad_Data_Science/')
